# %%
print('hello world')

# %% [markdown]
# # DataFrame

# %% [markdown]
# ## 生成DF

# %%
# dict > df
import pandas as pd
import numpy as np

sample_dict = {
    'open' : [1, 2, 3, 4],
    'close' : [5, 6, 7, 8]
}

df = pd.DataFrame(sample_dict)
