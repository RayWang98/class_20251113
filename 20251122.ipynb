# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
df1 = yf.download('0050.TW', start = '2024-01-01', end = '2024-12-31')
df2 = yf.download('0050.TW', start = '2025-01-01', end = '2025-12-31')
# Out:
# C:\Users\say08\AppData\Local\Temp\ipykernel_38852\3780320379.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df1 = yf.download('0050.TW', start = '2024-01-01', end = '2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# C:\Users\say08\AppData\Local\Temp\ipykernel_38852\3780320379.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df2 = yf.download('0050.TW', start = '2025-01-01', end = '2025-12-31')
# [*********************100%***********************]  1 of 1 completed
